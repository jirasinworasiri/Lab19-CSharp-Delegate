// %% [markdown]
// # Lab 19 Exercise 1

// %% [markdown]
// ## Delegate

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab19_Ex01
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// // 2. add target method to delegate
// MyDelegate myDel1 = new MyDelegate(MyMethod);
// MyDelegate myDel2 = MyMethod;
//
// // 3. Invoke delegate
// myDel1("Hello World");
// myDel1.Invoke("Hello Mars");
// myDel2("Hello Saturn");
//
// static  void  MyMethod(string message)
// {
//     System.Console.WriteLine(message);
// }
//
// // 1. declare delegate
// public delegate void MyDelegate(string message);
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab19_Ex01
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab19_Ex01
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// MyDelegate ถูกประกาศเป็น delegate ที่รับพารามิเตอร์เป็น string และไม่มีค่าผลลัพธ์ (void).
// การใช้ myDel1("Hello World"); เรียกเมทอด MyMethod ผ่าน delegate myDel1.
//
// การใช้ myDel1.Invoke("Hello Mars"); ทำให้เรียกเมทอด MyMethod โดยใช้เมทอด Invoke()
