// %% [markdown]
// # Lab 19 Exercise 9

// %% [markdown]
// ## Action

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab19_Ex09
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// // Action
// Action a = Print;
// a();
//
// Action<int, int, int> s = PrintSum;
// s(4, 5, 6);
//
// Action<int, int> sum = (a, b) =>
// {
//     var x = a + b;
//     System.Console.WriteLine("result = " + x);
// };
// sum(8, 2);
//
//
// static void Print()
// {
//     System.Console.WriteLine("Hello World");
// }
// static void PrintSum(int a, int b, int c)
// {
//     System.Console.WriteLine($"sum = {a + b + c}");
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab19_Ex09
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab19_Ex09
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// การใช้ Action แบบไม่มีพารามิเตอร์
// การใช้ Action แบบมีพารามิเตอร์ 3 ตัว
// การใช้ Action แบบมีพารามิเตอร์ 2 ตัวและใช้ Lambda Expression
