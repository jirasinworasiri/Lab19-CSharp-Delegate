// %% [markdown]
// # Lab 19 Exercise 7

// %% [markdown]
// ## Lambda expression

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab19_Ex07
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// // Lambda expression
// Square getSquare = x=> x*x ; // 2. define lambda expression
//
// int num = 9;
// int sqr = getSquare(num);
// System.Console.WriteLine($"Square value of {num} is {sqr}");
//
// delegate int Square(int num);  // 1. declare delegate
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab19_Ex07
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab19_Ex07
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// การสร้าง Lambda Expression
// getSquare คือ delegate ที่ชี้ไปยัง lambda expression x => x * x, ซึ่งรับพารามิเตอร์ x และคำนวณค่ากำลังสองของมัน (x * x). Lambda expression คือรูปแบบสั้นๆ
// การเรียกใช้ Lambda Expression ผ่าน Delegate
